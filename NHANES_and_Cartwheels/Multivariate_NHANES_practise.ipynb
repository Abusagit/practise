# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import numpy as np
import os
os.chdir(r'C:\Users\Fyodor\PycharmProjects\untitled\Coursera')

# %%
df = pd.read_csv('nhanes_2015_2016.csv')
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %% [markdown]
# ## Question 1
# Make a scatterplot showing the relationship between the first and second measurements of diastolic blood pressure (BPXDI1 and BPXDI2). Also obtain the 4x4 matrix of correlation coefficients among the first two systolic and the first two diastolic blood pressure measures.

# %%
# scatterplot:
sns.scatterplot(x='BPXDI1', y='BPXDI2', data=df)
# Out:
# <AxesSubplot:xlabel='BPXDI1', ylabel='BPXDI2'>

# %%
correlations = df[['BPXSY1', 'BPXDI1', 'BPXSY2', 'BPXDI2']].dropna().corr()
correlations
# Out:
#           BPXSY1    BPXDI1    BPXSY2    BPXDI2
# BPXSY1  1.000000  0.317497  0.962287  0.277681
# BPXDI1  0.317497  1.000000  0.329843  0.884722
# BPXSY2  0.962287  0.329843  1.000000  0.298392
# BPXDI2  0.277681  0.884722  0.298392  1.000000

# %% [markdown]
# ## Question 2
# Construct a grid of scatterplots between the first systolic and the first diastolic blood pressure measurement. Stratify the plots by gender (rows) and by race/ethnicity groups (columns).

# %%
corr_plots = sns.FacetGrid(data=df, row='RIAGENDR', col='RIDRETH1', a).map(plt.scatter, 'BPXSY1', 'BPXDI1').add_legend()
corr_plots
